# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime

# %%
filename = "bitcoin:USD.csv"
bUS = pd.read_csv(filename)

# %%
ax = plt.plot(bUS["Timestamp"],bUS["Weighted Price"])
ax.set_xticks([])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-85110f52c543> in <module>
#       1 ax = plt.plot(bUS["Timestamp"],bUS["Weighted Price"])
# ----> 2 ax.set_xticks([])
#
# AttributeError: 'list' object has no attribute 'set_xticks'

# %%
(bUS["Timestamp"][0])
# Out:
# '2021-09-25 00:00:00'

# %%
split = bUS["Timestamp"].str.split("-")
day = [split[i][2].split(" ") for i in range(len(split))]
date = pd.DataFrame({"year":[split[i][0] for i in range(len(split))],"month":[split[i][1] for i in range(len(split))],
                     "day": [day[i][0] for i in range(len(day))]})

# %%
bUS["TimeStamp"] = [datetime.fromtimestamp(bUS["Timestamp"][i]) for i in range(bUS.shape[0])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-a5b495604705> in <module>
# ----> 1 bUS["TimeStamp"] = [datetime.fromtimestamp(bUS["Timestamp"][i]) for i in range(bUS.shape[0])]
#
# <ipython-input-28-a5b495604705> in <listcomp>(.0)
# ----> 1 bUS["TimeStamp"] = [datetime.fromtimestamp(bUS["Timestamp"][i]) for i in range(bUS.shape[0])]
#
# TypeError: an integer is required (got type str)

# %%
bUS
# Out:
#               Timestamp      Open      High       Low     Close  Volume (BTC)  \
# 0   2021-09-25 00:00:00  42835.88  43010.69  41689.60  42722.19        879.20
# 1   2021-09-26 00:00:00  42699.10  43956.38  40808.00  43204.73       1659.78
# 2   2021-09-27 00:00:00  43162.82  44377.70  42130.00  42189.81       1936.65
# 3   2021-09-28 00:00:00  42154.87  42778.93  40888.00  41049.00       2246.85
# 4   2021-09-29 00:00:00  41024.21  42595.93  40750.00  41542.90       1804.78
# 5   2021-09-30 00:00:00  41537.56  44117.74  41427.87  43834.43       2614.50
# 6   2021-10-01 00:00:00  43835.47  48500.00  43291.07  48171.86       3446.87
# 7   2021-10-02 00:00:00  48185.61  48361.83  47468.15  47685.80       1361.84
# 8   2021-10-03 00:00:00  47644.63  49225.55  47119.87  48235.93       1164.60
# 9   2021-10-04 00:00:00  48231.04  49530.53  46900.00  49242.14       2737.78
# 10  2021-10-05 00:00:00  49283.89  51914.68  49075.00  51501.19       2206.60
# ...
